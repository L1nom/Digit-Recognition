# %% [markdown]
# This code uses the tensorflow starter code available on their website to test and train the MNIST data set. We then feed images to the model to predict the outcome.

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.2991 - accuracy: 0.9134
# Epoch 2/10
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1407 - accuracy: 0.9580
# Epoch 3/10
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.1060 - accuracy: 0.9684
# Epoch 4/10
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.0875 - accuracy: 0.9731
# Epoch 5/10
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.0738 - accuracy: 0.9770
# Epoch 6/10
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.0649 - accuracy: 0.9794
# Epoch 7/10
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.0598 - accuracy: 0.9806
# Epoch 8/10
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.0522 - accuracy: 0.9828
# Epoch 9/10
# ...

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageGrab, Image
from tensorflow import keras

# %% [markdown]
# The first for loop uses the model to predict images of pixel length 30, before the image is resized to 28x28
# The first for loop uses the model to predict images of pixel length 10, before the image is resized to 28x28
# The first for loop uses the model to predict images of pixel length 20, before the image is resized to 28x28
# seems like size 10 is best

# %%
for x in range(0,10):
    img = Image.open(f'{x}.png')
    img = np.array(img)
    img = np.invert(np.array([img]))
#     img = img.reshape(1,28,28,1)
    img = img/255
    predict = model.predict(img)
    print(np.argmax(predict))
# Out:
# 6
# 1
# 2
# 3
# 4
# 3
# 2
# 3
# 6
# 6

# %%
for x in range(10,20):
    img = Image.open(f'{x}.png')
    img = np.array(img)
    img = np.invert(np.array([img]))
#     img = img.reshape(1,28,28,1)
    img = img/255
    predict = model.predict(img)
    print(np.argmax(predict))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 3
# 8
# 3

# %%
for x in range(20,30):
    img = Image.open(f'{x}.png')
    img = np.array(img)
    img = np.invert(np.array([img]))
#     img = img.reshape(1,28,28,1)
    img = img/255
    predict = model.predict(img)
    print(np.argmax(predict))
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 2
# 3
# 3
# 3
